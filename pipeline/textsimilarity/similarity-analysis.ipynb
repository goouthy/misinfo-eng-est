# %% [markdown]
# ### Similarity analysis

# %%
import pandas as pd
from plots import cos_sim_plot, counts_plot, annt_plot

# %%
data = pd.read_parquet(f'over-threshold_.75.parquet')

cos_sim_plot(data)

# %%
counts50 = pd.read_parquet(f'counts-over-threshold_.5.parquet')

counts_plot(counts50)

# %%
counts75 = pd.read_parquet(f'counts-over-threshold_.75.parquet')

counts_plot(counts75)

# %%
gold = pd.read_parquet(f'goldstandard-annotations.parquet')

annt_plot(gold)

# %%
gold['Similarity'].value_counts(normalize=True)
# Out:
# Similarity
# Dissimilar            0.470
# Similar (Subtopic)    0.402
# Similar               0.122
# Somewhat similar      0.006
# Name: proportion, dtype: float64

# %%
gold['Stance'].value_counts(normalize=True)
# Out:
# Stance
# Same         0.784615
# Different    0.215385
# Name: proportion, dtype: float64

# %%
gold['True Label'].value_counts(normalize=True)
# Out:
# True Label
# Not misinformation    0.598
# Misinformation        0.388
# Not sure              0.014
# Name: proportion, dtype: float64

# %%
select = gold[gold['True Label'] != 'Not sure']
select['True Label'].value_counts()
# Out:
# True Label
# Not misinformation    299
# Misinformation        194
# Name: count, dtype: int64
