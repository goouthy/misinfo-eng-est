# %% [markdown]
# ### Pipeline #8 output analysis
# ###### Li Merila. Thesis, march 2024.

# %%
import pandas as pd
from plots import cos_sim_plot, counts_plot

# %%
data = pd.read_parquet(f'over-threshold.parquet')

cos_sim_plot(data)

# %%
counts = pd.read_parquet(f'counts-over-threshold_.5.parquet')

counts_plot(counts)
