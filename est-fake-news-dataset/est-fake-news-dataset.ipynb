# %% [markdown]
# ### Estonian misinformation news articles dataset, focusing on health topics

# %%
import pandas as pd

# %%
df = pd.read_parquet("est-fake-news-dataset.parquet")

# %%
df[["Label (By Human)", "Label (By Model)"]].value_counts().plot(kind='bar', figsize=(10, 5), grid=False);
