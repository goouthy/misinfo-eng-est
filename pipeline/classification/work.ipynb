# %%
import os

data_dir = '.\\pipeline\\classification\\data\\'

# Construct absolute path
abs_data_dir = os.path.abspath(data_dir)
print(f"Absolute path to data directory: {abs_data_dir}")
print(f"Absolute path to dataset: {os.path.join(abs_data_dir, 'goldstandard-dataset.parquet')}")
# Out:
# Absolute path to data directory: c:\Users\LI\Desktop\STUDY\UNIWORK\MASTERS\THESIS\misinfo-eng-est\misinfo-eng-est\pipeline\classification\pipeline\classification\data
# Absolute path to dataset: c:\Users\LI\Desktop\STUDY\UNIWORK\MASTERS\THESIS\misinfo-eng-est\misinfo-eng-est\pipeline\classification\pipeline\classification\data\goldstandard-dataset.parquet

# %%
# from matplotlib import font_manager
# for font in font_manager.findSystemFonts():
#     print(font)

# %%
import pandas as pd
from utils import compute_metrics, test_predictions, print_values
from plots import stats_plot, distr_plot, out_distr

cls1testpreds = pd.read_parquet('data/cls1-XLM-RoBERTa-test-predictions.parquet')

distr_plot(cls1testpreds, ontop=1)
