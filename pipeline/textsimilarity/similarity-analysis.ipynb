# %% [markdown]
# ### Similarity analysis

# %%
import pandas as pd
from plots import cos_sim_plot, counts_plot

# %%
data = pd.read_parquet(f'over-threshold_.75.parquet')
data = data[data['Cosine Similarity Score'] != 1]

cos_sim_plot(data, output="simdistr75")

# %%
counts50 = pd.read_parquet(f'counts-over-threshold_.5.parquet')

counts_plot(counts50, output="simmatch5")

# %%
counts75 = pd.read_parquet(f'counts-over-threshold_.75.parquet')

counts_plot(counts75)

# %%
gold = pd.read_parquet("gold-annotation-all.parquet")

annt_plot(gold)
# Out:
# c:\Users\LI\Desktop\STUDY\UNIWORK\MASTERS\THESIS\misinfo-eng-est\misinfo-eng-est\pipeline\textsimilarity\plots.py:53: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=0)
# c:\Users\LI\Desktop\STUDY\UNIWORK\MASTERS\THESIS\misinfo-eng-est\misinfo-eng-est\pipeline\textsimilarity\plots.py:53: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=0)
# c:\Users\LI\Desktop\STUDY\UNIWORK\MASTERS\THESIS\misinfo-eng-est\misinfo-eng-est\pipeline\textsimilarity\plots.py:53: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels, rotation=0)

# %%
gold['Similarity'].value_counts(normalize=True)
# Out:
# Similarity
# Dissimilar            0.476
# Similar (Subtopic)    0.398
# Similar               0.118
# Somewhat similar      0.008
# Name: proportion, dtype: float64

# %%
gold['Stance'].value_counts(normalize=True)
# Out:
# Stance
# Same         0.788235
# Different    0.211765
# Name: proportion, dtype: float64

# %%
gold['True Label'].value_counts(normalize=True)
# Out:
# True Label
# Not misinformation    0.612
# Misinformation        0.388
# Name: proportion, dtype: float64
